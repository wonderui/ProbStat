# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('cell_phones.xls')

# %%
data[data['Year'] == 3]
# Out:
#     Math Verbal Credits Year Exer  Sleep  Veg? Cell
# 14   450    430      13    3    0    8.0    no  yes
# 15   660    630      16    3   15    8.0  some  yes
# 17   720    720      17    3   45    6.5    no   no
# 28   740    800      16    3    0    6.0    no   no
# 35   500    650      12    3    0    7.0    no   no
# 40     *      *      16    3    0    4.5  some  yes
# 42   460    530       *    3    0    5.5    no  yes
# 46     *      *      17    3   30    4.0    no   no
# 58   590    600      15    3   30    6.5    no  yes
# 63   480    480      16    3  120    7.0    no  yes
# 64   690    600      20    3    0    7.0    no   no
# 74   610    680      15    3   30    6.5    no  yes
# 87     *      *      16    3    0    7.5    no  yes
# 90   620    490      17    3   30    7.5    no  yes
# 99   680    580      14    3   60    7.0    no  yes
# 104  640    620      14    3   90    5.5    no  yes
# 125  680    650      14    3    0    8.0    no  yes
# ...
