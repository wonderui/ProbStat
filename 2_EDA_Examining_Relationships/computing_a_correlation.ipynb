# %%
import pandas as pd
# %matplotlib inline

data = pd.read_excel('animals.xls', names = ['animal', 'gestation', 'longevity'])

data
# Out:
#            animal  gestation  longevity
# 0          baboon        187         20
# 1     bear, black        219         18
# 2   bear, grizzly        225         25
# 3     bear, polar        240         20
# 4          beaver        122          5
# 5         buffalo        278         15
# 6           camel        406         12
# 7             cat         63         12
# 8      chimpanzee        231         20
# 9        chipmunk         31          6
# 10            cow        284         15
# 11           deer        201          8
# 12            dog         61         12
# 13         donkey        365         12
# 14       elephant        645         40
# 15            elk        250         15
# 16            fox         52          7
# 17        giraffe        425         10
# 18           goat        151          8
# 19        gorilla        257         20
# 20     guinea pig         68          4
# 21   hippopotamus        238         25
# ...

# %%
data.plot(kind = 'scatter', x = 'gestation', y = 'longevity', title = 'Animals gestation and longevity')

# %%
data.corr()
# Out:
#            gestation  longevity
# gestation    1.00000    0.66324
# longevity    0.66324    1.00000

# %%
data['gestation'].corr(data['longevity'])
# Out:
# 0.66323967485850455

# %%
data.sort_values('gestation')[:-1].corr()
# Out:
#            gestation  longevity
# gestation   1.000000   0.519039
# longevity   0.519039   1.000000
